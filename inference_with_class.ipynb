# %%
from inference_utils_sem import load_sam_model, load_category_names, run_inference_with_semantic, show_results
from PIL import Image

generator = load_sam_model()
id2name = load_category_names()

# 예시 이미지
img_path = "/data/FoodSeg103/FoodSeg103/Images/img_dir/test/00000048.jpg"
image = Image.open(img_path).convert("RGB")

original, overlay = run_inference_with_semantic(image, generator, id2name)
show_results(original, overlay)
# Out:
# /home/jeongin/FoodSAM/mmseg/models/builder.py:61: UserWarning: train_cfg and test_cfg is deprecated, please specify them in model
#   'please specify them in model', UserWarning)
# load pre-trained weight from imagenet21k
# Use load_from_local loader

# %%
from inference_utils_sem import load_sam_model, load_category_names, run_inference_with_semantic, show_results
from PIL import Image

generator = load_sam_model()
id2name = load_category_names()

# 예시 이미지
img_path = "dataset/FoodSeg103/Images/img_dir/test/00004428.jpg"
image = Image.open(img_path).convert("RGB")

original, overlay = run_inference_with_semantic(image, generator, id2name)
show_results(original, overlay)
# Out:
# /home/jeongin/FoodSAM/mmseg/models/builder.py:61: UserWarning: train_cfg and test_cfg is deprecated, please specify them in model
#   'please specify them in model', UserWarning)
# load pre-trained weight from imagenet21k
# Use load_from_local loader
